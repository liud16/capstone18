# %%
class feature_analysis:
    
    def match_peaks():
        """
        This function takes the deconvoluted peaks found with 'peak_finder'
        and determines if they are similar enough to be the "feature".
        
        Input format will be determined by 'peak_finder' class.
        
        Similarity will be determined using FastDTW.
        
        Output will separate arrays/functions of similar peaks into
        unique data sets for each feature.
        """
        
    def describe_peaks():
        """
        This function takes the sorted features and generates a data frame of
        the peak attributes for each temporal slice.
        
        Input will be data set of features separated by match_peaks function.
        
        Data Frame will be created with the following indices:
        Time, Position, Intensity, Width
        
        For a given time, the position, intensity, and width of lineshapes
        will be appended to this data frame - generating a complete description
        of each peak for every feature over the time frame of the experiment.
        
        Output will be filled data frames for any given number of peaks found
        with 'peak_finder' and classified to be the same feature with match_peaks.
        """
        
    def visualize_features():
        """
        This function takes the descriptors of each peak for a given feature and 
        plots them against time to visualize the feature's kinetics.
        
        Input will be data frames generated by describe_peaks.
        
        The following visualizations will be generated using Matplotlib:
        Intensity vs Time
        Width vs Time
        Position vs Time
        
        Additionally, the decay function for Intensity vs Time plots will be
        calculated, and reported for each peak. (This might be a separate func?)
        
        Output will be plots detailing the kinetics of each feature and an 
        indicator of which features have the same decay kinetics.
        """
